# %%
pip install nasdaq-data-link
# Out:
# Requirement already satisfied: nasdaq-data-link in c:\users\rajpu\anaconda3\lib\site-packages (1.0.4)
# Requirement already satisfied: six in c:\users\rajpu\anaconda3\lib\site-packages (from nasdaq-data-link) (1.16.0)
# Requirement already satisfied: more-itertools in c:\users\rajpu\anaconda3\lib\site-packages (from nasdaq-data-link) (9.0.0)
# Requirement already satisfied: pandas>=0.14 in c:\users\rajpu\anaconda3\lib\site-packages (from nasdaq-data-link) (1.5.2)
# Requirement already satisfied: inflection>=0.3.1 in c:\users\rajpu\anaconda3\lib\site-packages (from nasdaq-data-link) (0.5.1)
# Requirement already satisfied: requests>=2.7.0 in c:\users\rajpu\anaconda3\lib\site-packages (from nasdaq-data-link) (2.27.1)
# Requirement already satisfied: python-dateutil in c:\users\rajpu\anaconda3\lib\site-packages (from nasdaq-data-link) (2.8.2)
# Requirement already satisfied: numpy>=1.8 in c:\users\rajpu\anaconda3\lib\site-packages (from nasdaq-data-link) (1.24.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rajpu\anaconda3\lib\site-packages (from pandas>=0.14->nasdaq-data-link) (2021.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\rajpu\anaconda3\lib\site-packages (from requests>=2.7.0->nasdaq-data-link) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rajpu\anaconda3\lib\site-packages (from requests>=2.7.0->nasdaq-data-link) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\rajpu\anaconda3\lib\site-packages (from requests>=2.7.0->nasdaq-data-link) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rajpu\anaconda3\lib\site-packages (from requests>=2.7.0->nasdaq-data-link) (3.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
import datetime 

from statsmodels.tsa.seasonal import seasonal_decompose

import nasdaqdatalink

import warnings 
warnings.filterwarnings('ignore')

import seaborn as sns
sns.set()

# %%
start4 = datetime.date(2015,1,1)
end4 = datetime.date(2022,12,31)

ticker4 = 'OPEC/ORB'

# %%
df = nasdaqdatalink.get(dataset = ticker4 , start_date = start4,end_date = end4 )
print (f'downloaded {df.shape[0]} ROWS & {df.shape[1]} Columns of {ticker4}')
# Out:
# downloaded 2064 ROWS & 1 Columns of OPEC/ORB

# %%
df4 = df.copy()

# %%
df4.rename(columns={"Value":"price"},inplace = True)

# %%
oil_long_run_mean = np.round(df4['price'].mean(), 1)
print(oil_long_run_mean)
# Out:
# 61.0

# %%
df4.plot(figsize=(12,8),color=('indigo'),linewidth=0.8);
plt.title(f"Price of {ticker4}")

for eachyear in range(start4.year , end4.year):
    plt.axvline(pd.to_datetime(str(eachyear)+'-12-31'), color='black', linestyle='--', alpha=0.4)
plt.axhline(df4['price'].mean(),label = 'Mean price',color = 'maroon',linestyle = '--',alpha = 0.7)
plt.legend()

# %%
window_length21 = 21
window_length252 = 252

df4['rolling_21d_mean'] = df4.price.rolling(window=window_length21).mean()
df4['rolling_21d_std'] = df4.price.rolling(window=window_length21).std()

df4['rolling_252d_mean'] = df4.price.rolling(window=window_length252).mean()
df4['rolling_252d_std'] = df4.price.rolling(window=window_length252).std()

# %%
df4.dropna()
# Out:
#             price  rolling_21d_mean  rolling_21d_std  rolling_252d_mean  \
# Date
# 2015-12-21  30.74         35.948571         3.179441          50.004960
# 2015-12-22  31.15         35.605714         3.293689          49.923095
# 2015-12-23  31.25         35.208571         3.292061          49.853175
# 2015-12-24  32.17         34.844762         3.178313          49.796032
# 2015-12-28  31.71         34.466667         3.047687          49.744127
# ...           ...               ...              ...                ...
# 2022-12-23  80.58         79.891905         2.984858         100.547976
# 2022-12-27  82.23         79.817143         2.900548         100.557143
# 2022-12-28  81.96         79.913810         2.938082         100.562341
# 2022-12-29  80.39         79.769524         2.829688         100.555952
# 2022-12-30  81.29         79.681905         2.747731         100.554722
#
#             rolling_252d_std
# Date
# 2015-12-21          8.049791
# 2015-12-22          8.136106
# 2015-12-23          8.220467
# 2015-12-24          8.293108
# 2015-12-28          8.365184
# ...                      ...
# 2022-12-23         12.092549
# 2022-12-27         12.077716
# 2022-12-28         12.069393
# 2022-12-29         12.079680
# 2022-12-30         12.081633
#
# [1813 rows x 5 columns]

# %%
df4.plot(figsize = (18,8),linewidth = 0.8,color='blue')

for eachyear in range(start4.year,end4.year):
    plt.axvline(pd.to_datetime(str(eachyear)+'-12-31'), color='black', linestyle='--', alpha=0.4)
    
plt.title("OPEC benchmark crude oil prices over time", fontsize=20)
plt.xlabel("Date")
plt.ylabel("Price per barrel (in US$)")
# Out:
# Text(0, 0.5, 'Price per barrel (in US$)')

# %%
df4x = df.copy()

# %%
df4x = df4x.resample("M").mean()

# %%
df4x.rename(columns={'Value': 'monthly_mean_price'}, inplace=True)

# %%
df4x['Year'] = df4x.index.year

# %%
df4x['month'] = df4x.index.month_name().str[:3]

# %%
sns.set(rc={'figure.figsize':(16,8)})

df4xbox = sns.boxplot(x = 'month',y = 'monthly_mean_price',data = df4x,order=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 
                          'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],palette = 'Set2')
